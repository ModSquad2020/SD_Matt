# %%
import pandas as pd
import re
df = pd.read_csv('eColi_tRNA_modomics.csv')

# %%
newcolumns = ['tRNASequence' if n==5 else x.strip() for n, x in enumerate(df.columns)]
df.columns = newcolumns
for column in df.columns:
    print(column, end='---')
# Out:
# Type---AA type---Anticodon---Organism---Organellum---tRNASequence---MINTbase---

# %%
df
# Out:
#      Type AA type Anticodon           Organism            Organellum  \
# 0   tRNA     Ala       VGC   Escherichia coli   prokaryotic cytosol
# 1   tRNA     Ala       GGC   Escherichia coli   prokaryotic cytosol
# 2   tRNA     Arg       ICG   Escherichia coli   prokaryotic cytosol
# 3   tRNA     Arg       CCG   Escherichia coli   prokaryotic cytosol
# 4   tRNA     Arg       UCU   Escherichia coli   prokaryotic cytosol
# 5   tRNA     Asn       GUU   Escherichia coli   prokaryotic cytosol
# 6   tRNA     Asp       ⊄UC   Escherichia coli   prokaryotic cytosol
# 7   tRNA     Cys       GCA   Escherichia coli   prokaryotic cytosol
# 8   tRNA     Gln       UUG   Escherichia coli   prokaryotic cytosol
# 9   tRNA     Gln       CUG   Escherichia coli   prokaryotic cytosol
# 10  tRNA     Glu       SUC   Escherichia coli   prokaryotic cytosol
# 11  tRNA     Gly       CCC   Escherichia coli   prokaryotic cytosol
# 12  tRNA     Gly       {CC   Escherichia coli   prokaryotic cytosol
# 13  tRNA     Gly       GCC   Escherichia coli   prokaryotic cytosol
# 14  tRNA     His       GUG   Escherichia coli   prokaryotic cytosol
# 15  tRNA     Ile       GAU   Escherichia coli   prokaryotic cytosol
# 16  tRNA     Ile       CAU   Escherichia coli   prokaryotic cytosol
# 17  tRNA     Leu       CAG   Escherichia coli   prokaryotic cytosol
# 18  tRNA     Leu       GAG   Escherichia coli   prokaryotic cytosol
# 19  tRNA     Leu       )AA   Escherichia coli   prokaryotic cytosol
# 20  tRNA     Leu       BAA   Escherichia coli   prokaryotic cytosol
# 21  tRNA     Lys       SUU   Escherichia coli   prokaryotic cytosol
# 22  tRNA     Met       MAU   Escherichia coli   prokaryotic cytosol
# 23  tRNA     Phe       GAA   Escherichia coli   prokaryotic cytosol
# 24  tRNA     Pro       CGG   Escherichia coli   prokaryotic cytosol
# 25  tRNA     Sec       UCA   Escherichia coli   prokaryotic cytosol
# 26  tRNA     Ser       UGA   Escherichia coli   prokaryotic cytosol
# 27  tRNA     Ser       CGA   Escherichia coli   prokaryotic cytosol
# 28  tRNA     Ser       GCU   Escherichia coli   prokaryotic cytosol
# 29  tRNA     Ser       GGA   Escherichia coli   prokaryotic cytosol
# 30  tRNA     Thr       GGU   Escherichia coli   prokaryotic cytosol
# 31  tRNA     Thr       GGU   Escherichia coli   prokaryotic cytosol
# 32  tRNA     Trp       CCA   Escherichia coli   prokaryotic cytosol
# 33  tRNA     Tyr       QUA   Escherichia coli   prokaryotic cytosol
# 34  tRNA     Tyr       QUA   Escherichia coli   prokaryotic cytosol
# 35  tRNA     Val       VAC   Escherichia coli   prokaryotic cytosol
# 36  tRNA     Val       GAC   Escherichia coli   prokaryotic cytosol
# 37  tRNA     Val       GAC   Escherichia coli   prokaryotic cytosol
# 38  tRNA     Ini       CAU   Escherichia coli   prokaryotic cytosol
# 39  tRNA     Ini       CAU   Escherichia coli   prokaryotic cytosol
# 40  tRNA     Glu       {UC   Escherichia coli   prokaryotic cytosol
# 41  tRNA     Leu       UAG   Escherichia coli   prokaryotic cytosol
# 42  tRNA     Thr       UGU   Escherichia coli   prokaryotic cytosol
#
#                                          tRNASequence  MINTbase
# 0   -GGGGCUAUAGCUCAGCdihydrouridine[show modificat...       NaN
# 1   -GGGGCUAUAGCUCAGCdihydrouridine[show modificat...       NaN
# 2   -GCAUCCG4-thiouridine[show modification pathwa...       NaN
# 3   -GCGCCCGUAGCUCAGCdihydrouridine[show modificat...       NaN
# 4   -GCGCCCUUAGCUCAGUU-GGAU-AGAGCAACGAC2-thiocytid...       NaN
# 5   -UCCUCUG4-thiouridine[show modification pathwa...       NaN
# 6   -GGAGCGG4-thiouridine[show modification pathwa...       NaN
# 7   -GGCGCGU4-thiouridine[show modification pathwa...       NaN
# 8   -UGGGGUA4-thiouridine[show modification pathwa...       NaN
# 9   -UGGGGUA4-thiouridine[show modification pathwa...       NaN
# 10  -GUCCCCUUCGUCpseudouridine[show modification p...       NaN
# 11  -GCGGGCG4-thiouridine[show modification pathwa...       NaN
# 12  -GCGGGCAUCGUAUAAU--GGCU-AUUACCUCAGCCU5-methyla...       NaN
# 13  -GCGGGAA4-thiouridine[show modification pathwa...       NaN
# 14  GGUGGCUA4-thiouridine[show modification pathwa...       NaN
# 15  -AGGCUUGUAGCUCAGGdihydrouridine[show modificat...       NaN
# 16  -GGCCCCU4-thiouridine[show modification pathwa...       NaN
# 17  -GCGAAGGUGGCGGAAdihydrouridine[show modificati...       NaN
# 18  -GCCGAGGUGGUGGAAdihydrouridine[show modificati...       NaN
# 19  -GCCCGGA4-thiouridine[show modification pathwa...       NaN
# 20  -GCCGAAG4-thiouridine[show modification pathwa...       NaN
# 21  -GGGUCGUUAGCUCAGdihydrouridine[show modificati...       NaN
# 22  -GGCUACG4-thiouridine[show modification pathwa...       NaN
# 23  -GCCCGGA4-thiouridine[show modification pathwa...       NaN
# 24  -CGGUGAUUGGCGCAGCCUGGdihydrouridine[show modif...       NaN
# 25  -_AAGAUCG4-thiouridine[show modification pathw...       NaN
# 26  -GGAAGUG4-thiouridine[show modification pathwa...       NaN
# 27  -GGAGAGAUGCCGGAGC--2′-O-methylguanosine[show m...       NaN
# 28  -GGUGAGG4-thiouridine[show modification pathwa...       NaN
# 29  -GGUGAGG4-thiouridine[show modification pathwa...       NaN
# 30  -GCUGAUAUGGCUCAGdihydrouridine[show modificati...       NaN
# 31  -GCUGAUAUAGCUCAGdihydrouridine[show modificati...       NaN
# 32  -AGGGGCG4-thiouridine[show modification pathwa...       NaN
# 33  -GGUGGGG4-thiouridine[show modification pathwa...       NaN
# 34  -GGUGGGG4-thiouridine[show modification pathwa...       NaN
# 35  -GGGUGAU4-thiouridine[show modification pathwa...       NaN
# 36  -GCGUCCG4-thiouridine[show modification pathwa...       NaN
# 37  -GCGUUCA4-thiouridine[show modification pathwa...       NaN
# 38  -CGCGGGG4-thiouridine[show modification pathwa...       NaN
# 39  -CGCGGGG4-thiouridine[show modification pathwa...       NaN
# 40  -GUCCCCU4-thiouridine[show modification pathwa...       NaN
# 41  -GCGGGAGUGGCGAAAdihydrouridine[show modificati...       NaN
# 42  -GCCGACUUAGCUCAGUA-GGdihydrouridine[show modif...       NaN

# %%
tRNA = df.loc[0][5]
tRNA
# Out:
# '-GGGGCUAUAGCUCAGCdihydrouridine[show modification pathway]\');return false">D-GGG--AGAGCGCCUGCUUuridine 5-oxyacetic acid[show modification pathway]\');return false">VGCACGCAGGAG-------------------7-methylguanosine[show modification pathway]\');return false">7UCUGCGGTpseudouridine[show modification pathway]\');return false">PCGAUCCCGCAUAGCUCCACCA'

# %% [markdown]
# # Making a pattern to take out text
# The plan is to make a regular expression that takes out that wierd text that shows up in front of modifications

# %%
#matches a lowercase letter or a number followed by -
#   p in pseudouridine or 7- in 7-methylguanosine
#need the #- because otherwise it would match the character
#MODOMICS uses to denote modifications in the code.

pattern = r'([a-z]|\d-).+?>'
pattern = re.compile(pattern)

# %%
def findAnnotation(tRNAText):
    '''
    This method uses the pattern above to search an 
    input string for modomics style annotation.
    '''
    matches = pattern.finditer(tRNAText)
    for match in matches:
        print (match)

# %% [markdown]
# # Headers freaking have spaces
# The freaking MODOMICS headers have weird spaces so I needed to strip them.
#
# # Difficult to pull info from df
# Also for whatever reason I need to jump through hoops in order to iterate over the rows of the df and pull out the info I need. That is why the following code is so weird. All its doing is getting seq, aa, aCodon info and feeding sequence string to the pattern matching method.

# %%
for index in range(0, df[['tRNASequence', 'AA type', 'Anticodon']].shape[0]):
    seq, aa, aCodon = list( df[['tRNASequence', 'AA type', 'Anticodon']].loc[index] )
    print(aa, aCodon, '\n')
    findAnnotation(seq)
    print('\n\n')
# Out:
# Ala  VGC
#
# <re.Match object; span=(17, 75), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(95, 163), match='uridine 5-oxyacetic acid[show modification pathwa>
# <re.Match object; span=(194, 255), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(264, 321), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ala  GGC
#
# <re.Match object; span=(17, 75), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(126, 187), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(196, 253), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Arg  ICG
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(74, 132), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(137, 195), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(208, 266), match='2-thiocytidine[show modification pathway]\');retu>
# <re.Match object; span=(268, 319), match='inosine[show modification pathway]\');return fals>
# <re.Match object; span=(322, 383), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(411, 472), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(473, 551), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(559, 616), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Arg  CCG
#
# <re.Match object; span=(17, 75), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(80, 138), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(151, 209), match='2-thiocytidine[show modification pathway]\');retu>
# <re.Match object; span=(214, 275), match='1-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(303, 364), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(373, 430), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Arg  UCU
#
# <re.Match object; span=(35, 93), match='2-thiocytidine[show modification pathway]\');retu>
# <re.Match object; span=(95, 165), match='5-methylaminomethyluridine[show modification path>
# <re.Match object; span=(169, 241), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(244, 301), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(335, 392), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Asn  GUU
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(136, 194), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(210, 263), match='queuosine[show modification pathway]\');return fa>
# <re.Match object; span=(267, 339), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(341, 398), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(424, 485), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(494, 551), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Asp  ⊄UC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(136, 194), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(195, 253), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(268, 330), match='glutamyl-queuosine[show modification pathway]\');>
# <re.Match object; span=(333, 394), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(422, 483), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(492, 549), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(559, 616), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Cys  GCA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(78, 136), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(139, 197), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(208, 265), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(270, 350), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(352, 409), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(444, 501), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Gln  UUG
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(81, 140), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(142, 200), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(219, 276), match='methyluridine[show modification pathway]\');retur>
# <re.Match object; span=(278, 362), match='5-carboxymethylaminomethyl-2-thiouridine[show mod>
# <re.Match object; span=(365, 426), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(427, 484), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(520, 577), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Gln  CUG
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(81, 140), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(142, 200), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(219, 276), match='methyluridine[show modification pathway]\');retur>
# <re.Match object; span=(281, 342), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(343, 400), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(401, 458), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(493, 550), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Glu  SUC
#
# <re.Match object; span=(13, 70), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(94, 171), match='5-methylaminomethyl-2-thiouridine[show modificati>
# <re.Match object; span=(174, 235), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(272, 329), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Gly  CCC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(78, 136), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(192, 249), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Gly  {CC
#
# <re.Match object; span=(37, 107), match='5-methylaminomethyluridine[show modification path>
# <re.Match object; span=(147, 204), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Gly  GCC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(132, 190), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(194, 252), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(299, 360), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(369, 426), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# His  GUG
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(132, 190), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(194, 252), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(268, 321), match='queuosine[show modification pathway]\');return fa>
# <re.Match object; span=(324, 385), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(386, 443), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(444, 501), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(527, 588), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(597, 654), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ile  GAU
#
# <re.Match object; span=(17, 75), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(79, 137), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(138, 196), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(215, 287), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(315, 376), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(377, 455), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(463, 520), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(530, 587), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ile  CAU
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(81, 140), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(142, 200), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(201, 259), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(274, 328), match='2-lysidine[show modification pathway]\');return f>
# <re.Match object; span=(332, 404), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(406, 463), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(489, 550), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(551, 629), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(637, 694), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Leu  CAG
#
# <re.Match object; span=(16, 74), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(75, 133), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(140, 199), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(201, 259), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(278, 339), match='1-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(340, 397), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(399, 456), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(490, 547), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Leu  GAG
#
# <re.Match object; span=(16, 74), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(75, 133), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(140, 199), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(201, 259), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(278, 339), match='1-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(340, 397), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(433, 490), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Leu  )AA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(139, 198), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(200, 258), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(272, 329), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(331, 420), match='5-carboxymethylaminomethyl-2′-O-methyluridine[sho>
# <re.Match object; span=(423, 503), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(505, 562), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(597, 654), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Leu  BAA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(139, 198), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(200, 258), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(272, 329), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(336, 394), match='methylcytidine[show modification pathway]\');retu>
# <re.Match object; span=(397, 477), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(479, 536), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(571, 628), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Lys  SUU
#
# <re.Match object; span=(16, 74), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(75, 133), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(137, 195), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(211, 288), match='5-methylaminomethyl-2-thiouridine[show modificati>
# <re.Match object; span=(292, 364), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(366, 423), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(449, 510), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(511, 589), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(597, 654), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Met  MAU
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(132, 190), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(197, 256), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(258, 316), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(317, 375), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(391, 451), match='4-acetylcytidine[show modification pathway]\');re>
# <re.Match object; span=(455, 527), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(529, 586), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(612, 673), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(674, 752), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(760, 817), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Phe  GAA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(136, 194), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(208, 265), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(270, 350), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(352, 409), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(435, 496), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(497, 575), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(583, 640), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Pro  CGG
#
# <re.Match object; span=(21, 79), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(98, 159), match='1-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(187, 248), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(257, 314), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Sec  UCA
#
# <re.Match object; span=(9, 66), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(78, 136), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(156, 222), match='6-isopentenyladenosine[show modification pathway]>
# <re.Match object; span=(259, 316), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ser  UGA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(81, 140), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(142, 200), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(201, 259), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(277, 335), match='methylcytidine[show modification pathway]\');retu>
# <re.Match object; span=(337, 405), match='uridine 5-oxyacetic acid[show modification pathwa>
# <re.Match object; span=(408, 488), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(525, 582), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ser  CGA
#
# <re.Match object; span=(24, 83), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(86, 144), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(162, 242), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(279, 336), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ser  GCU
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(79, 137), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(150, 208), match='2-thiocytidine[show modification pathway]\');retu>
# <re.Match object; span=(214, 286), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(323, 380), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ser  GGA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(81, 140), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(142, 200), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(201, 259), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(280, 337), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(371, 428), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Thr  GGU
#
# <re.Match object; span=(16, 74), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(75, 133), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(137, 195), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(215, 297), match='6-methyl-N6-threonylcarbamoyladenosine[show modif>
# <re.Match object; span=(325, 386), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(395, 452), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Thr  GGU
#
# <re.Match object; span=(16, 74), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(75, 133), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(137, 195), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(215, 297), match='6-methyl-N6-threonylcarbamoyladenosine[show modif>
# <re.Match object; span=(325, 386), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(395, 452), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Trp  CCA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(132, 190), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(194, 252), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(271, 329), match='methylcytidine[show modification pathway]\');retu>
# <re.Match object; span=(334, 414), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(442, 503), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(512, 569), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Tyr  QUA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(66, 123), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(138, 197), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(215, 268), match='queuosine[show modification pathway]\');return fa>
# <re.Match object; span=(269, 326), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(328, 408), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(410, 467), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(502, 559), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Tyr  QUA
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(66, 123), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(138, 197), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(215, 268), match='queuosine[show modification pathway]\');return fa>
# <re.Match object; span=(269, 326), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(328, 408), match='2-methylthio-N6-isopentenyladenosine[show modific>
# <re.Match object; span=(410, 467), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(502, 559), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Val  VAC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(74, 132), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(152, 220), match='uridine 5-oxyacetic acid[show modification pathwa>
# <re.Match object; span=(224, 285), match='6-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(313, 374), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(383, 440), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Val  GAC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(132, 190), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(194, 252), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(253, 311), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(357, 418), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(419, 497), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(505, 562), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Val  GAC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(73, 131), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(132, 190), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(194, 252), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(253, 311), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(357, 418), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(419, 497), match='3-(3-amino-3-carboxypropyl)uridine[show modificat>
# <re.Match object; span=(505, 562), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ini  CAU
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(78, 136), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(155, 213), match='methylcytidine[show modification pathway]\');retu>
# <re.Match object; span=(246, 307), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(316, 373), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Ini  CAU
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(78, 136), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(155, 213), match='methylcytidine[show modification pathway]\');retu>
# <re.Match object; span=(255, 312), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Glu  {UC
#
# <re.Match object; span=(8, 65), match='4-thiouridine[show modification pathway]\');retur>
# <re.Match object; span=(70, 127), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(151, 228), match='5-methylaminomethyl-2-thiouridine[show modificati>
# <re.Match object; span=(231, 292), match='2-methyladenosine[show modification pathway]\');r>
# <re.Match object; span=(329, 386), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Leu  UAG
#
# <re.Match object; span=(16, 74), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(75, 133), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(140, 199), match='methylguanosine[show modification pathway]\');ret>
# <re.Match object; span=(217, 285), match='uridine 5-oxyacetic acid[show modification pathwa>
# <re.Match object; span=(288, 349), match='1-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(350, 407), match='pseudouridine[show modification pathway]\');retur>
# <re.Match object; span=(443, 500), match='pseudouridine[show modification pathway]\');retur>
#
#
#
# Thr  UGU
#
# <re.Match object; span=(21, 79), match='dihydrouridine[show modification pathway]\');retu>
# <re.Match object; span=(98, 156), match='methylcytidine[show modification pathway]\');retu>
# <re.Match object; span=(158, 226), match='uridine 5-oxyacetic acid[show modification pathwa>
# <re.Match object; span=(230, 302), match='6-threonylcarbamoyladenosine[show modification pa>
# <re.Match object; span=(330, 391), match='7-methylguanosine[show modification pathway]\');r>
# <re.Match object; span=(400, 457), match='pseudouridine[show modification pathway]\');retur>

# %% [markdown]
# # Recap
# The pattern matching code seems to be working fine, now I need to find a way to have it excize the matches it finds. Maybe write a method that pulls the boundries and stitches them together into a final string.
#
# ## Example
# 'Hello world it is a beautiful day'
# (6, 12) -- world
# (20, 30) -- beautiful
#
# ### excision
# (0, 6)(12, 20)(30, 32)
# 'Hello it is a day'
